# %%
import torch
import numpy as np
import gensim
from utils import loadpkl,print_tableIDs,flatten_1_deg

# %%
model = gensim.models.KeyedVectors.load_word2vec_format(
    '/home/vibhav_student/global_data/GoogleNews-vectors-negative300.bin',
    binary=True)

# %%
dog = model['dog']
print(dog.shape)
print(dog[:10])
# Out:
# (300,)
# [ 0.05126953 -0.02233887 -0.17285156  0.16113281 -0.08447266  0.05737305
#   0.05859375 -0.08251953 -0.01538086 -0.06347656]

# %%
x = loadpkl('./data/w_all_data/x_tokenised_preprocessed_qfix_pad_unk.pkl')

# %%
print_tableIDs(x[0],vocab)
# Out:
# [['the_adventures_of_priscilla_queen_of_the_desert'], ['stephan_elliott'], ['australia'], ['musical_comedy_drama'], ['<PAD>']]
# [['bar_girls'], ['marita_giovanni'], ['united_states'], ['drama'], ['<PAD>']]
# [['lust_liberation'], ['robert_lee_king'], ['united_states'], ['drama'], ['<PAD>']]
# [['coming_out_under_fire'], ['arthur_dong'], ['united_states'], ['documentary'], ['<PAD>']]
# [['ed_wood_film'], ['tim_burton'], ['united_states'], ['comedy_drama'], ['<PAD>']]
# [['drop'], ['gregg_bordowitz'], ['united_states'], ['documentary'], ['<PAD>']]
# [['four_weddings_and_a_funeral'], ['mike_newell_director'], ['england'], ['romantic_comedy_drama'], ['<PAD>']]
# [['a_friend_dorothy'], ["raoul_o'connell"], ['united_states'], ['short_drama'], ['<PAD>']]
# [['go_fish_film'], ['rose_troche'], ['united_states'], ['romantic_drama'], ['<PAD>']]
# [['heavenly_creatures'], ['peter_jackson'], ['england'], ['crime_drama'], ['<PAD>']]
# ...

# %%
vocab = loadpkl('./data/w_all_data/vocab_5-15_unk_qfix.pkl')

# %%
l = []
for i in vocab:
    l.append(i.split('_'))

# %%
words = list(set(flatten_1_deg(l)))

# %%
c = 0
for i in words:
    try:
        model.get_vector(i)
    except:
        try:
            model.get_vector(i.capitalize())
        except:
            c+=1

# %%
c
# Out:
# 567769

# %%
c/len(words)
# Out:
# 0.6555701681967603

# %%
model.get_vector('dog')[:10],model.get_vector('Dog')[:10]
# Out:
# (array([ 0.05126953, -0.02233887, -0.17285156,  0.16113281, -0.08447266,
#          0.05737305,  0.05859375, -0.08251953, -0.01538086, -0.06347656],
#        dtype=float32),
#  array([-2.46093750e-01,  1.23381615e-05, -1.72851562e-01,  2.40234375e-01,
#         -1.63574219e-02,  8.11767578e-03, -1.47460938e-01,  1.16210938e-01,
#          1.17187500e-01, -2.00195312e-01], dtype=float32))

# %%
model.most_similar(positive=[np.random.rand(300)], topn=1)
# Out:
# [('birthday_Vicky_Gunvalson', 0.2178681343793869)]

# %%
len(list(set([i.lower() for i in model.index2entity]))),len(model.index2entity)
# Out:
# (2702150, 3000000)

# %%
# Out:
# ['</s>',
#  'in',
#  'for',
#  'that',
#  'is',
#  'on',
#  '##',
#  'The',
#  'with',
#  'said',
#  'was',
#  'the',
#  'at',
#  'not',
#  'as',
#  'it',
#  'be',
#  'from',
#  'by',
#  'are',
#  'I',
#  'have',
#  'he',
#  'will',
#  'has',
#  '####',
#  'his',
#  'an',
#  'this',
#  'or',
#  'their',
#  'who',
#  'they',
#  'but',
#  '$',
#  'had',
#  'year',
#  'were',
#  'we',
#  'more',
#  '###',
#  'up',
#  'been',
#  'you',
#  'its',
#  'one',
#  'about',
#  'would',
#  'which',
#  'out',
#  'can',
#  'It',
#  'all',
#  'also',
#  'two',
#  'after',
#  'first',
#  'He',
#  'do',
#  'time',
#  'than',
#  'when',
#  'We',
#  'over',
#  'last',
#  'new',
#  'other',
#  'her',
#  'people',
#  'into',
#  'In',
#  'our',
#  'there',
#  'A',
#  'she',
#  'could',
#  'just',
#  'years',
#  'some',
#  'U.S.',
#  'three',
#  'million',
#  'them',
#  'what',
#  'But',
#  'so',
#  'no',
#  'like',
#  'if',
#  'only',
#  'percent',
#  'get',
#  'did',
#  'him',
#  'game',
#  'back',
# ...
